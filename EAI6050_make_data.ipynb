# %% [markdown]
# <a href="https://colab.research.google.com/github/pranay8297/BitcoinSummaryGeneration/blob/main/EAI6050_make_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install newsapi-python

# %%
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key='1d7833d782b74e1cae5eccdd37c49a94')

# %%
from datetime import datetime, timedelta
num_days=30
end_date = datetime.utcnow()
start_date = end_date - timedelta(days=num_days)
all_articles = newsapi.get_everything(q='bitcoin', from_param = start_date,
                                      to= end_date,
                                      language='en',
                                      sort_by='relevancy',
                                      page=1)

# %%
import pandas as pd

# %%
articles_df = pd.DataFrame(all_articles['articles'])

# %%
articles_df.head()
# Out:
#                                               source  \
# 0                   {'id': 'wired', 'name': 'Wired'}
# 1  {'id': 'business-insider', 'name': 'Business I...
# 2                  {'id': None, 'name': 'ReadWrite'}
# 3  {'id': 'business-insider', 'name': 'Business I...
# 4                   {'id': 'wired', 'name': 'Wired'}
#
#                          author  \
# 0                  Joel Khalili
# 1                 George Glover
# 2              Kliment Dukovski
# 3               Dan DeFrancesco
# 4  Andy Greenberg, Andrew Couts
#
#                                                title  \
# 0  Fresh Bitcoin Hype Shows Crypto Just Can’t Hel...
# 1                             Bitcoin just won't die
# 2  How to Buy Bitcoin Minetrix in 2023 – Complete...
# 3                          Bitcoin is back (sort of)
# 4  The Startup That Transformed the Hack-for-Hire...
#
#                                          description  \
# 0  After crashes, scandals, and SBF’s guilty verd...
# ...

# %%
articles_df['published_at_new'] = pd.to_datetime(articles_df['publishedAt'])

# %%
articles_df.head()
# Out:
#                                               source  \
# 0                   {'id': 'wired', 'name': 'Wired'}
# 1  {'id': 'business-insider', 'name': 'Business I...
# 2                  {'id': None, 'name': 'ReadWrite'}
# 3  {'id': 'business-insider', 'name': 'Business I...
# 4                   {'id': 'wired', 'name': 'Wired'}
#
#                          author  \
# 0                  Joel Khalili
# 1                 George Glover
# 2              Kliment Dukovski
# 3               Dan DeFrancesco
# 4  Andy Greenberg, Andrew Couts
#
#                                                title  \
# 0  Fresh Bitcoin Hype Shows Crypto Just Can’t Hel...
# 1                             Bitcoin just won't die
# 2  How to Buy Bitcoin Minetrix in 2023 – Complete...
# 3                          Bitcoin is back (sort of)
# 4  The Startup That Transformed the Hack-for-Hire...
#
#                                          description  \
# 0  After crashes, scandals, and SBF’s guilty verd...
# ...

# %%
articles_df.columns
# Out:
# Index(['source', 'author', 'title', 'description', 'url', 'urlToImage',
#        'publishedAt', 'content', 'published_at_new'],
#       dtype='object')

# %%
articles_df = articles_df.drop(columns = ['source', 'author', 'url', 'urlToImage', 'publishedAt'])

# %%
articles_df.head()
# Out:
#                                                title  \
# 0  Fresh Bitcoin Hype Shows Crypto Just Can’t Hel...
# 1                             Bitcoin just won't die
# 2  How to Buy Bitcoin Minetrix in 2023 – Complete...
# 3                          Bitcoin is back (sort of)
# 4  The Startup That Transformed the Hack-for-Hire...
#
#                                          description  \
# 0  After crashes, scandals, and SBF’s guilty verd...
# 1  Bitcoin is outperforming both the S&P 500 and ...
# 2  Bitcoin Minetrix is a crypto project aiming to...
# 3  A recent surge in bitcoin's price is the lates...
# 4  Plus: The FBI's baffling inaction on a ransomw...
#
#                                              content          published_at_new
# 0  The prospect that US residents may soon be abl... 2023-11-29 12:00:00+00:00
# 1  FTX founder Sam Bankman-Fried.Michael M Santia... 2023-11-10 13:54:08+00:00
# 2  Bitcoin Minetrix is a crypto project aiming to... 2023-11-27 11:55:20+00:00
# ...

# %%
articles_df.published_at_new[0].month
# Out:
# 11

# %%
# !pip install cryptocompare

# %%
import cryptocompare
from datetime import datetime,timedelta

# Set your API key (optional, but recommended for increased usage limits)
cryptocompare.cryptocompare._set_api_key_parameter('90c3ee566bc6b79a30d1fdbbc8ae91206ab03635ab1b0b24fe7448c4c4b7678c')

# Define the cryptocurrency symbol and base currency
symbol = 'BTC'
base_currency = 'USD'

# Calculate the end date (today) and start date (30 days ago)
# end_date = datetime.strptime('2023-12-05', "%Y-%m-%d")
# start_date = datetime.strptime('2023-11-05', "%Y-%m-%d")

# Convert dates to Unix timestamps
start_timestamp = int(start_date.timestamp())
end_timestamp = int(end_date.timestamp())

# Fetch historical price data
historical_data = cryptocompare.get_historical_price_day(
    symbol, currency=base_currency, toTs=end_timestamp
)
filtered_data = [data_point for data_point in historical_data if data_point['time'] >= start_timestamp]

# %%
import pandas as pd

# Create a DataFrame
price_df = pd.DataFrame(filtered_data, columns=['time', 'high', 'low', 'close', 'open'])
# Convert timestamp to datetime
price_df['date'] = pd.to_datetime(price_df['time'], unit='s')

# Select and reorder columns
price_df = price_df[['date', 'high', 'low', 'close', 'open']]
price_df
# Out:
#          date      high       low     close      open
# 0  2023-11-09  37990.51  35557.78  36704.14  35638.33
# 1  2023-11-10  37536.44  36342.27  37321.51  36704.14
# 2  2023-11-11  37417.29  36701.83  37142.22  37321.51
# 3  2023-11-12  37233.45  36747.05  37079.76  37142.22
# 4  2023-11-13  37429.52  36358.00  36482.51  37079.76
# 5  2023-11-14  36752.31  34788.17  35551.21  36482.51
# 6  2023-11-15  37977.31  35374.22  37884.19  35551.21
# 7  2023-11-16  37951.14  35512.38  36162.42  37884.19
# 8  2023-11-17  36780.63  35873.70  36626.32  36162.42
# 9  2023-11-18  36853.45  36212.85  36591.19  36626.32
# 10 2023-11-19  37529.10  36411.61  37388.64  36591.19
# 11 2023-11-20  37770.11  36767.05  37476.66  37388.64
# 12 2023-11-21  37665.29  35753.93  35758.72  37476.66
# 13 2023-11-22  37866.63  35656.41  37424.20  35758.72
# 14 2023-11-23  37646.06  36892.34  37299.18  37424.20
# 15 2023-11-24  38432.07  37262.39  37737.05  37299.18
# ...

# %%
# price_df.to_csv('/content/drive/MyDrive/EAI6120DS/bitcoin_prices_new.csv', index = None)

# %%
# !ls /content/drive/MyDrive/EAI6120DS
# Out:
# bitcoin_prices.csv  news_description.csv  score_card.csv  score_card_new.csv

# %%
# df_1 = pd.read_csv('/content/drive/MyDrive/EAI6120DS/news_description.csv')
# df_2 = pd.read_csv('/content/drive/MyDrive/EAI6120DS/bitcoin_prices_new.csv')

# %%
df_1=articles_df
df_2=price_df

# %%
df_1.head()
# Out:
#                                                title  \
# 0  Fresh Bitcoin Hype Shows Crypto Just Can’t Hel...
# 1                             Bitcoin just won't die
# 2  How to Buy Bitcoin Minetrix in 2023 – Complete...
# 3                          Bitcoin is back (sort of)
# 4  The Startup That Transformed the Hack-for-Hire...
#
#                                          description  \
# 0  After crashes, scandals, and SBF’s guilty verd...
# 1  Bitcoin is outperforming both the S&P 500 and ...
# 2  Bitcoin Minetrix is a crypto project aiming to...
# 3  A recent surge in bitcoin's price is the lates...
# 4  Plus: The FBI's baffling inaction on a ransomw...
#
#                                              content          published_at_new
# 0  The prospect that US residents may soon be abl... 2023-11-29 12:00:00+00:00
# 1  FTX founder Sam Bankman-Fried.Michael M Santia... 2023-11-10 13:54:08+00:00
# 2  Bitcoin Minetrix is a crypto project aiming to... 2023-11-27 11:55:20+00:00
# ...

# %%
df_1.columns
# Out:
# Index(['title', 'description', 'content', 'published_at_new'], dtype='object')

# %%
df_2.head()
# Out:
#         date      high       low     close      open
# 0 2023-11-09  37990.51  35557.78  36704.14  35638.33
# 1 2023-11-10  37536.44  36342.27  37321.51  36704.14
# 2 2023-11-11  37417.29  36701.83  37142.22  37321.51
# 3 2023-11-12  37233.45  36747.05  37079.76  37142.22
# 4 2023-11-13  37429.52  36358.00  36482.51  37079.76

# %%
# df_1 = df_1.drop(columns = ['Unnamed: 0'])

# %%
df_1.head()
# Out:
#                                                title  \
# 0  Fresh Bitcoin Hype Shows Crypto Just Can’t Hel...
# 1                             Bitcoin just won't die
# 2  How to Buy Bitcoin Minetrix in 2023 – Complete...
# 3                          Bitcoin is back (sort of)
# 4  The Startup That Transformed the Hack-for-Hire...
#
#                                          description  \
# 0  After crashes, scandals, and SBF’s guilty verd...
# 1  Bitcoin is outperforming both the S&P 500 and ...
# 2  Bitcoin Minetrix is a crypto project aiming to...
# 3  A recent surge in bitcoin's price is the lates...
# 4  Plus: The FBI's baffling inaction on a ransomw...
#
#                                              content          published_at_new
# 0  The prospect that US residents may soon be abl... 2023-11-29 12:00:00+00:00
# 1  FTX founder Sam Bankman-Fried.Michael M Santia... 2023-11-10 13:54:08+00:00
# 2  Bitcoin Minetrix is a crypto project aiming to... 2023-11-27 11:55:20+00:00
# ...

# %%
# df_2.loc[df_2['date'] == '2023-11-05']

# %%
df_1['date'] = pd.to_datetime(df_1['published_at_new']).dt.date
df_2['date'] = pd.to_datetime(df_2['date'])

# %%
df_1.head()
# Out:
#                                                title  \
# 0  Fresh Bitcoin Hype Shows Crypto Just Can’t Hel...
# 1                             Bitcoin just won't die
# 2  How to Buy Bitcoin Minetrix in 2023 – Complete...
# 3                          Bitcoin is back (sort of)
# 4  The Startup That Transformed the Hack-for-Hire...
#
#                                          description  \
# 0  After crashes, scandals, and SBF’s guilty verd...
# 1  Bitcoin is outperforming both the S&P 500 and ...
# 2  Bitcoin Minetrix is a crypto project aiming to...
# 3  A recent surge in bitcoin's price is the lates...
# 4  Plus: The FBI's baffling inaction on a ransomw...
#
#                                              content  \
# 0  The prospect that US residents may soon be abl...
# 1  FTX founder Sam Bankman-Fried.Michael M Santia...
# 2  Bitcoin Minetrix is a crypto project aiming to...
# 3  Malte Mueller/Getty Images\r\n<ul>\n<li>This p...
# ...

# %%
df_1 = df_1.drop('published_at_new', axis=1)

# %%
df_1.head()
# Out:
#                                                title  \
# 0  Fresh Bitcoin Hype Shows Crypto Just Can’t Hel...
# 1                             Bitcoin just won't die
# 2  How to Buy Bitcoin Minetrix in 2023 – Complete...
# 3                          Bitcoin is back (sort of)
# 4  The Startup That Transformed the Hack-for-Hire...
#
#                                          description  \
# 0  After crashes, scandals, and SBF’s guilty verd...
# 1  Bitcoin is outperforming both the S&P 500 and ...
# 2  Bitcoin Minetrix is a crypto project aiming to...
# 3  A recent surge in bitcoin's price is the lates...
# 4  Plus: The FBI's baffling inaction on a ransomw...
#
#                                              content        date
# 0  The prospect that US residents may soon be abl...  2023-11-29
# 1  FTX founder Sam Bankman-Fried.Michael M Santia...  2023-11-10
# 2  Bitcoin Minetrix is a crypto project aiming to...  2023-11-27
# ...

# %%
df_2.head()
# Out:
#         date      high       low     close      open
# 0 2023-11-09  37990.51  35557.78  36704.14  35638.33
# 1 2023-11-10  37536.44  36342.27  37321.51  36704.14
# 2 2023-11-11  37417.29  36701.83  37142.22  37321.51
# 3 2023-11-12  37233.45  36747.05  37079.76  37142.22
# 4 2023-11-13  37429.52  36358.00  36482.51  37079.76

# %%
# df_1.date[0].date() - timedelta(days = 1)

# %%
df_1.date[0].day
# Out:
# 29

# %%
df_2.date[0].day
# Out:
# 9

# %%
df_2=df_2.sort_values('date')
df_2.head()
# Out:
#         date      high       low     close      open
# 0 2023-11-09  37990.51  35557.78  36704.14  35638.33
# 1 2023-11-10  37536.44  36342.27  37321.51  36704.14
# 2 2023-11-11  37417.29  36701.83  37142.22  37321.51
# 3 2023-11-12  37233.45  36747.05  37079.76  37142.22
# 4 2023-11-13  37429.52  36358.00  36482.51  37079.76

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np

# %%
df=df_2

# %%
# Normalize the data
columns_to_normalize = ['high', 'close', 'low', 'open']
for column in columns_to_normalize:
    df[column] = (df[column] - df[column].mean()) / df[column].std()

# %%
# Convert data to PyTorch tensors
data = torch.FloatTensor(df[['high', 'close', 'low', 'open']].values).unsqueeze(1)

# %%
# Define the Transformer model
class TransformerModel(nn.Module):
    def __init__(self, input_size, d_model, nhead, num_encoder_layers):
        super(TransformerModel, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.transformer = nn.Transformer(d_model=d_model, nhead=nhead, num_encoder_layers=num_encoder_layers)
        self.fc = nn.Linear(d_model, 1)

    def forward(self, x):
        x = self.embedding(x)
        x = self.transformer(x, x)
        x = self.fc(x)
        return x

# %%
# Hyperparameters
input_size = 4
d_model = 10
nhead = 2
num_encoder_layers = 2
lr = 0.0001
epochs = 200

# %%
# Instantiate the model, loss function, and optimizer
model = TransformerModel(input_size, d_model, nhead, num_encoder_layers)
criterion = nn.SmoothL1Loss()
optimizer = optim.Adam(model.parameters(), lr=lr)
# optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
# Training loop
for epoch in range(epochs):
    optimizer.zero_grad()
    output = model(data[:-7])  # Input: all except the last 7 days
    target = data[7:]          # Target: the next 7 days
    loss = criterion(output, target)
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:933: UserWarning: Using a target size (torch.Size([23, 1, 4])) that is different to the input size (torch.Size([23, 1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
# Epoch [10/200], Loss: 0.4066
# Epoch [20/200], Loss: 0.3923
# Epoch [30/200], Loss: 0.4071
# Epoch [40/200], Loss: 0.3109
# Epoch [50/200], Loss: 0.3054
# Epoch [60/200], Loss: 0.2959
# Epoch [70/200], Loss: 0.2561
# Epoch [80/200], Loss: 0.2834
# Epoch [90/200], Loss: 0.3474
# Epoch [100/200], Loss: 0.2276
# Epoch [110/200], Loss: 0.2626
# Epoch [120/200], Loss: 0.2938
# Epoch [130/200], Loss: 0.2023
# Epoch [140/200], Loss: 0.1984
# Epoch [150/200], Loss: 0.2532
# Epoch [160/200], Loss: 0.2561
# Epoch [170/200], Loss: 0.2220
# Epoch [180/200], Loss: 0.1790
# Epoch [190/200], Loss: 0.2319
# ...

# %%
# Evaluation
model.eval()
with torch.no_grad():
    forecast = model(data[:-7])

# %%
# Denormalize the data for visualization
for i, column in enumerate(columns_to_normalize):
    df[column] = df[column] * df[column].std() + df[column].mean()

forecast = forecast.numpy() * df[columns_to_normalize].std().values + df[columns_to_normalize].mean().values

# %%
# Plot the results
plt.figure(figsize=(17, 10))
plt.plot(df['date'], df['close'], label='Actual Data', marker='o')
plt.plot(df['date'][:-7], forecast[:, 0, 0], label='Forecast', linestyle='dashed', marker='o')
plt.title('Transformer Model Forecasting')
plt.xlabel('Date')
plt.ylabel('Normalized Value')
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Assuming you have a DataFrame with 'date', 'high', 'close', 'low', and 'open' columns
# Replace 'your_data.csv' with the actual path or URL to your dataset
# Adjust the CSV reading part according to your actual data loading method

# Example DataFrame loading
# df = pd.read_csv('your_data.csv')
# df['date'] = pd.to_datetime(df['date'])
# df = df.sort_values('date')

# For the sake of the example, let's generate synthetic data
# np.random.seed(42)
# date_range = pd.date_range('2022-01-01', '2022-12-31', freq='D')
# df = pd.DataFrame({
#     'date': date_range,
#     'high': np.random.rand(len(date_range)),
#     'close': np.random.rand(len(date_range)),
#     'low': np.random.rand(len(date_range)),
#     'open': np.random.rand(len(date_range))
# })

# Normalize the data
columns_to_normalize = ['high', 'close', 'low', 'open']
for column in columns_to_normalize:
    df[column] = (df[column] - df[column].mean()) / df[column].std()

# Convert data to PyTorch tensors
data = torch.FloatTensor(df[['high', 'close', 'low', 'open']].values).unsqueeze(1)

# Define the Transformer model with batch size
class TransformerModel(nn.Module):
    def __init__(self, input_size, d_model, nhead, num_encoder_layers):
        super(TransformerModel, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.transformer = nn.Transformer(d_model=d_model, nhead=nhead, num_encoder_layers=num_encoder_layers)
        self.fc = nn.Linear(d_model, 1)

    def forward(self, x):
        x = self.embedding(x)
        x = self.transformer(x, x)
        x = self.fc(x)
        return x

# Hyperparameters
input_size = 4  # Assuming 'high', 'close', 'low', 'open' columns
d_model = 8
nhead = 2
num_encoder_layers = 2
lr = 0.0001
epochs = 200
batch_size = 16  # Adjust this value

# Instantiate the model, loss function, and optimizer
model = TransformerModel(input_size, d_model, nhead, num_encoder_layers)
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9)

# Data loading with batch size
data_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, shuffle=True)

# Training loop with batches
for epoch in range(epochs):
    for batch in data_loader:
        optimizer.zero_grad()
        output = model(batch[:-7])  # Input: all except the last 7 days
        target = batch[7:]          # Target: the next 7 days
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}')

# Evaluation
model.eval()
with torch.no_grad():
    forecast = model(data[:-7])

# Denormalize the data for visualization
for i, column in enumerate(columns_to_normalize):
    df[column] = df[column] * df[column].std() + df[column].mean()

forecast = forecast.numpy() * df[columns_to_normalize].std().values + df[columns_to_normalize].mean().values

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['close'], label='Actual Data', marker='o')
plt.plot(df['date'][:-7], forecast[:, 0, 0], label='Forecast', linestyle='dashed', marker='o')
plt.title('Transformer Model Forecasting with Batch Size')
plt.xlabel('Date')
plt.ylabel('Normalized Value')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([9, 1, 4])) that is different to the input size (torch.Size([9, 1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ...

# %%
columns_to_normalize = ['high', 'close', 'low', 'open']
for column in columns_to_normalize:
    df[column] = (df[column] - df[column].mean()) / df[column].std()

# Convert data to PyTorch tensors
data = torch.FloatTensor(df[['high', 'close', 'low', 'open']].values).unsqueeze(1)
# Define the LSTM model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        _, (h_n, _) = self.lstm(x)
        x = self.fc(h_n[-1, :, :])  # Use the last hidden state
        return x

# Hyperparameters
input_size = 4  # Assuming 'high', 'close', 'low', 'open' columns
hidden_size = 5
num_layers = 2
lr = 0.00001
epochs = 200

# Instantiate the model, loss function, and optimizer
model = LSTMModel(input_size, hidden_size, num_layers)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

# Training loop
for epoch in range(epochs):
    optimizer.zero_grad()
    output = model(data[:-7])  # Input: all except the last 7 days
    target = data[7:]          # Target: the next 7 days
    loss = criterion(output, target)
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}')

# Evaluation
model.eval()
with torch.no_grad():
    forecast = model(data[:-7])

# Denormalize the data for visualization
for i, column in enumerate(columns_to_normalize):
    df[column] = df[column] * df[column].std() + df[column].mean()

forecast = forecast.numpy() * df[columns_to_normalize].std().values + df[columns_to_normalize].mean().values

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['close'], label='Actual Data', marker='o')
plt.plot(df['date'][:-7], forecast[:, 0], label='Forecast', linestyle='dashed', marker='o')
# plt.plot(df['date'][:-7], forecast.squeeze(), label='Forecast', linestyle='dashed', marker='o')
plt.title('LSTM Model Forecasting')
plt.xlabel('Date')
plt.ylabel('Normalized Value')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([23, 1, 4])) that is different to the input size (torch.Size([23, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [10/200], Loss: 1.3433
# Epoch [20/200], Loss: 1.3430
# Epoch [30/200], Loss: 1.3427
# Epoch [40/200], Loss: 1.3425
# Epoch [50/200], Loss: 1.3422
# Epoch [60/200], Loss: 1.3419
# Epoch [70/200], Loss: 1.3417
# Epoch [80/200], Loss: 1.3414
# Epoch [90/200], Loss: 1.3411
# Epoch [100/200], Loss: 1.3409
# Epoch [110/200], Loss: 1.3406
# Epoch [120/200], Loss: 1.3403
# Epoch [130/200], Loss: 1.3401
# Epoch [140/200], Loss: 1.3398
# Epoch [150/200], Loss: 1.3395
# Epoch [160/200], Loss: 1.3393
# Epoch [170/200], Loss: 1.3390
# Epoch [180/200], Loss: 1.3387
# Epoch [190/200], Loss: 1.3385
# Epoch [200/200], Loss: 1.3382

# %%
# # Generate synthetic time series data
# np.random.seed(42)
# time_steps = np.arange(0, 365, 1)
# data = np.sin(2 * np.pi * time_steps / 30) + np.random.normal(scale=0.1, size=len(time_steps))
df=df_2

# Normalize the data
data_mean = np.mean(data)
data_std = np.std(data)
data = (data - data_mean) / data_std

# Convert data to PyTorch tensors
data = torch.FloatTensor(data).view(-1, 1)

# Define the Transformer model
class TransformerModel(nn.Module):
    def __init__(self, input_size, d_model, nhead, num_encoder_layers):
        super(TransformerModel, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)  # Adjust input feature dimension
        self.transformer = nn.Transformer(d_model=d_model, nhead=nhead, num_encoder_layers=num_encoder_layers)
        self.fc = nn.Linear(d_model, 1)  # Adjust output feature dimension

    def forward(self, x):
        x = self.embedding(x)
        x = self.transformer(x, x)  # Pass x as both source and target
        x = self.fc(x)
        return x

# Hyperparameters
input_size = 1
d_model = 8
nhead = 2
num_encoder_layers = 2
lr = 0.001
epochs = 100

# Instantiate the model, loss function, and optimizer
model = TransformerModel(input_size, d_model, nhead, num_encoder_layers)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

# Training loop
for epoch in range(epochs):
    optimizer.zero_grad()
    output = model(data[:-7])  # Input: all except the last 7 days
    target = data[7:]          # Target: the next 7 days
    loss = criterion(output, target)
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch + 1}/{epochs}], Loss: {loss.item():.4f}')

# Evaluation
model.eval()
with torch.no_grad():
    forecast = model(data[:-7])

# Denormalize the data for visualization
data = data.numpy() * data_std + data_mean
forecast = forecast.numpy() * data_std + data_mean

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(time_steps, data, label='Actual Data')
plt.plot(time_steps[:-7], forecast, label='Forecast', linestyle='dashed')
plt.title('Transformer Model Forecasting')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# Epoch [10/100], Loss: 1.0521
# Epoch [20/100], Loss: 1.0219
# Epoch [30/100], Loss: 1.0044
# Epoch [40/100], Loss: 1.0081
# Epoch [50/100], Loss: 1.0109
# Epoch [60/100], Loss: 1.0059
# Epoch [70/100], Loss: 1.0018
# Epoch [80/100], Loss: 0.9938
# Epoch [90/100], Loss: 1.0096
# Epoch [100/100], Loss: 1.0027

# %%
huggingface_token = "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"

# %%
# !pip install -q transformers langchain accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.2/178.2 kB 17.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.6 MB/s eta 0:00:00

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
import torch
import transformers
from transformers import AutoTokenizer
from  langchain import LLMChain, HuggingFacePipeline, PromptTemplate

# %%
model = "meta-llama/Llama-2-7b-chat-hf"
tokenizer = AutoTokenizer.from_pretrained(model)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=3000,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
)
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the cpu and disk.

# %%
! pip install --upgrade pip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 8.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.2
#     Uninstalling pip-23.1.2:
#       Successfully uninstalled pip-23.1.2
# ...

# %%
import openai
import requests


crypto_price=df_1
aricle_texts=df_2
# Generate Summaries using GPT-2
openai.api_key = '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'

summaries = []
for text in article_texts:
    prompt = f"Summarize the following news article: {text} \n\nCrypto Price: {crypto_price}"
    response_gpt2 = openai.Completion.create(
        engine="davinci",  # or other available engines
        prompt=prompt,
        max_tokens=150  # adjust as needed
    )
    summary = response_gpt2.choices[0].text.strip()
    summaries.append(summary)

# Display or further process the generated summaries
for i, summary in enumerate(summaries):
    print(f"\nSummary for Article {i + 1}:\n{summary}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-29260760ac3f> in <cell line: 1>()
# ----> 1 import openai
#       2 import requests
#       3
#       4
#       5 crypto_price=df_1
#
# ModuleNotFoundError: No module named 'openai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
data_dict = {}

# %%
df_1.iloc[1].date, df_1.iloc[1].news.split(':')
# Out:
# (Timestamp('2023-11-06 00:00:00'),
#  ['The Dow, Nasdaq, and S&P 500 are all coming off of their strongest weekly performance of the year, with each gaining more than 5%. ',
#   ' Markets are looking for a new catalyst to drive fresh gains after a big week. Morgan Stanley and JPMorgan both warned the rally looks set to fade. ',
#   ' With immense anticipation building around Bitcoin spot ETF approval in the United States, one team of pioneers has developed a token directly linked to the Bitcoin ETF approval. Introducing Bitcoin ETF Token (BTCETF), a new project that rewards users as the E…'])

# %%
df_1.sort_values(by='date',ascending=True)

# %%
df_1

# %%
pd.Timestamp(df_1.date[0].date())
# Out:
# Timestamp('2023-11-05 00:00:00')

# %%
df_2.loc[df_2.date == pd.Timestamp(df_1.date[0].date())]
# Out:
#         date      high       low     close      open
# 1 2023-11-05  35393.84  34489.02  35039.47  35086.09

# %%
# !pip install ipdb
from ipdb import set_trace as st
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.2 MB/s eta 0:00:00
# ...

# %%
data_dict = {}
for i in range(len(df_1)):
  rec = df_1.iloc[i]
  this_day = rec.date
  prev_date = pd.Timestamp(this_day.date() - timedelta(days = 1))

  price_today = float(df_2.loc[df_2.date == this_day].high)
  price_yesterday = float(df_2.loc[df_2.date == prev_date].high)

  news_articles = rec.news

  data_dict[str(this_day.date())] = {'date': str(this_day.date()), 'high': price_today, 'high_yesterday': price_yesterday, 'news': news_articles}

# %%
data_dict

# %%
import json

# %%
with open('/content/drive/MyDrive/EAI6120DS/summary_data.json', 'w') as fp:
    json.dump(data_dict, fp)
